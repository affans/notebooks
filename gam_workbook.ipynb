# %%
# Working file for https://multithreaded.stitchfix.com/blog/2015/07/30/gam/ 
# downloaded pdf in onedrive/documents/generalized_additive_model....pdf

using Distributions 
using DataFrames
using Random

# %%
x = 0:0.1:(2*pi)
z = sin.(x)
y = z .+ rand(Normal(0, 0.5*std(z)))
df = DataFrame(x=x, z=z, y=y)
# Out:
# 63×3 DataFrame
# │ Row │ x       │ z          │ y          │
# │     │ Float64 │ Float64    │ Float64    │
# ├─────┼─────────┼────────────┼────────────┤
# │ 1   │ 0.0     │ 0.0        │ -0.113522  │
# │ 2   │ 0.1     │ 0.0998334  │ -0.0136886 │
# │ 3   │ 0.2     │ 0.198669   │ 0.0851473  │
# │ 4   │ 0.3     │ 0.29552    │ 0.181998   │
# │ 5   │ 0.4     │ 0.389418   │ 0.275896   │
# │ 6   │ 0.5     │ 0.479426   │ 0.365904   │
# │ 7   │ 0.6     │ 0.564642   │ 0.45112    │
# │ 8   │ 0.7     │ 0.644218   │ 0.530696   │
# │ 9   │ 0.8     │ 0.717356   │ 0.603834   │
# │ 10  │ 0.9     │ 0.783327   │ 0.669805   │
# ⋮
# │ 53  │ 5.2     │ -0.883455  │ -0.996977  │
# │ 54  │ 5.3     │ -0.832267  │ -0.945789  │
# │ 55  │ 5.4     │ -0.772764  │ -0.886286  │
# │ 56  │ 5.5     │ -0.70554   │ -0.819062  │
# │ 57  │ 5.6     │ -0.631267  │ -0.744789  │
# │ 58  │ 5.7     │ -0.550686  │ -0.664208  │
# │ 59  │ 5.8     │ -0.464602  │ -0.578124  │
# │ 60  │ 5.9     │ -0.373877  │ -0.487399  │
# ...
